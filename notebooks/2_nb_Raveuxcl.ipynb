# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Cargue el archivo dolar_2019_sii.csv a un dataframe que se llame dolar_2019 usando pandas. ¿Que argumento necesita pd.read_csv() para leer las columnas correctamente?
#
#  necesita el argunmento sep =";"

# %%
dolar_2019 = pd.read_csv("C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/raw/dolar_2019_sii.csv",sep =";")
dolar_2019 = dolar_2019[dolar_2019['Día'] != 'Promedio']
dolar_2019
# Out:
#    Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# 0    1     NaN  657,81  651,79  678,53     NaN     NaN  679,15  700,82
# 1    2  694,77     NaN     NaN  672,56  678,71     NaN  677,62  704,88
# 2    3  697,09     NaN     NaN  670,05  683,31  709,80  681,30     NaN
# 3    4  697,64  655,39  656,57  667,55     NaN  704,59  680,48     NaN
# 4    5     NaN  653,80  659,07  666,32     NaN  696,78  677,64  711,13
# 5    6     NaN  652,78  657,49     NaN  678,68  693,25     NaN  721,70
# 6    7  688,42  653,90  658,40     NaN  681,09  692,21     NaN  716,35
# 7    8  679,69  654,44  662,19  664,17  683,49     NaN  683,12  718,55
# 8    9  680,10     NaN     NaN  663,01  684,51     NaN  685,83  710,98
# 9   10  678,09     NaN     NaN  663,15  686,43  692,28  688,88     NaN
# 10  11  677,58  656,46  670,83  662,92     NaN  697,34  685,40     NaN
# 11  12     NaN  660,82  669,37  664,19     NaN  693,60  683,38  712,04
# ...

# %% [markdown]
# 2. Explore el archivo dolar_2020_sii.txt. ¿Qué estructura tiene, en que se diferencia y en qué es igual al dataframe anterior? ¿Qué método y argumento hay que usar para leer las columnas correctamente?. Carguelo en un dataframe llamado dolar_2020_txt.
#
# se diferencian en en formato, uno es csv y el otro txt, ademas del separador que en el anterior era ; y en este es |, tambien el nombre de las columnas no es el mismo. Contienen la misma informacion, el precio de el dolar por dia del ano
#
# Se tienen que ocupar los argumentos sep="|" y header = None

# %%
dolar_2020_txt = pd.read_csv("C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/raw/dolar_2020_sii.txt",sep ="|" ,
                            header = None)
dolar_2020_txt.columns = dolar_2019.columns
dolar_2020_txt = dolar_2020_txt[dolar_2020_txt['Día'] != 'Promedio']
dolar_2020_txt
# Out:
#    Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# 0    1     NaN     NaN     NaN  852,03     NaN  806,32  821,23     NaN
# 1    2  748,74     NaN  818,32  863,81     NaN  796,46  816,29     NaN
# 2    3  754,16  799,11  817,45  861,89     NaN  782,86  803,98  757,06
# 3    4     NaN  790,92  809,81     NaN  837,92  769,13     NaN  761,34
# 4    5     NaN  781,78  812,19     NaN  838,74  775,58     NaN  767,98
# 5    6  758,49  776,99  823,28  863,99  832,84     NaN  801,46  774,82
# 6    7  771,82  779,12     NaN  853,91  839,08     NaN  798,79  777,18
# 7    8  773,12     NaN     NaN  842,05  836,27  764,97  793,88     NaN
# 8    9  766,83     NaN  828,95  851,90     NaN  769,26  786,18     NaN
# 9   10  764,69  788,80  841,06     NaN     NaN  771,96  781,74  784,28
# 10  11     NaN  795,88  834,22     NaN  827,65  767,93     NaN  796,58
# 11  12     NaN  792,48  835,48     NaN  826,05  784,65     NaN  793,61
# ...

# %% [markdown]
# 3. Explore el archivo dolar_2020_sii_AA.txt. ¿Qué estructura tiene? ¿Será buena idea ocupar expresiones regulares para indicar el separador? (hint: sí). Carguelo en un dataframe llamado dolar_2020_regex y compárelo con el dataframe dolar_2020_txt. ¿Son exactamente iguales en la información que traen?

# %%
# Se carga el dataset dolar_2020_sii_AA.dat
dolar_2020_regex = pd.read_csv('C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/raw/dolar_2020_sii_AA.dat', 
                        sep=';',
                              header=None)
 
dolar_2020_regex
# Se debe ocupar expresión regular para poder visualizar de mejor forma el dataframe
dolar_2020_regex[0].replace(r'X[a-zA-ZÀ-ÿ\u00f1\u00d1]X',';',regex=True, inplace = True)
dolar_2020_regex
#se ocupa split y expand para tener una mejor visualización del dataframe
dolar_2020_regex = pd.DataFrame(dolar_2020_regex[0].str.split(';', expand=True) )
names = dolar_2019.columns
dolar_2020_regex.columns = names
dolar_2020_regex
# Para dejar los 3 dataframe homologados se debe rellenar los campos en blancos con Nan y luego
#Realizar la misma limpieza que en los demás dataframe como es no tomar en cuenta la ultima linea
#Transformar las variables a int float segun corrresponda y por ultimo crear el campo year con el año
#correspondiente

dolar_2020_regex = dolar_2020_regex.apply(lambda x: x.str.strip()).replace('', np.nan)
dolar_2020_regex = dolar_2020_regex[dolar_2020_regex['Día'] != 'Promedio']
dolar_2020_regex.head()
# Out:
#   Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago     Sep  \
# 0   1     NaN     NaN     NaN  852,03     NaN  806,32  821,23     NaN  776,46
# 1   2  748,74     NaN  818,32  863,81     NaN  796,46  816,29     NaN  770,59
# 2   3  754,16  799,11  817,45  861,89     NaN  782,86  803,98  757,06  771,45
# 3   4     NaN  790,92  809,81     NaN  837,92  769,13     NaN  761,34  773,71
# 4   5     NaN  781,78  812,19     NaN  838,74  775,58     NaN  767,98     NaN
#
#       Oct     Nov     Dic
# 0  788,15     NaN  767,29
# 1  785,04  771,92  760,16
# 2     NaN  769,17  755,34
# 3     NaN  758,53  752,03
# 4  790,81  757,16     NaN

# %% [markdown]
# 4. Haga las siguientes operaciones de wrangling y limpieza:
#
# Filtre sacando la última fila, arreglando y homogeneizando los encabezados para los tres dataframes
# Revise que los nombres de las columnas sean los mismos en cada dataframe.
# Cree una columna en cada uno de los tres dataframes que se llame year y que tenga el año correspondiente, y que su type sea int64.
# Convierta las comas a puntos en cada uno de los tres dataframes.
# Fuerce que todas las variables sean de tipo int o de tipo float.

# %%
dolar_2019["Year"] = 2019
dolar_2020_txt["Year"] = 2020
dolar_2020_regex["Year"] = 2020
type(dolar_2020_regex["Year"][0])

dolar_2019.replace(",",".", inplace = True, regex = True)
dolar_2020_txt.replace(",",".", inplace = True, regex = True)
dolar_2020_regex.replace(",",".", inplace = True, regex = True)

dolar_2019 = dolar_2019.astype(dtype = float)
dolar_2020_txt = dolar_2020_txt.astype(dtype = float)
dolar_2020_regex = dolar_2020_regex.astype(dtype = float)

# %% [markdown]
# 5. Exporte estos tres dataframes en la carpeta data/interim de la siguiente forma:
#
# dolar_2019 en formato csv, separado por comas, con nombre d2019.csv
#
# dolar_2020_txt en formato txt, separado por un espacio simple, con nombre d2020.txt.
#
# dolar_2020_regex en formato CSV, separado por ";", de nombre dolar_2020_excel.csv

# %%
dolar_2019.to_csv(r'C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/interim/d2019.csv' , sep =",")
dolar_2020_txt.to_csv(r'C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/interim/d2020.txt', sep =" ")
dolar_2020_regex.to_csv(r'C:/Users/Javier Vega/Documents/GitHub/tarea1-add/data/interim/dolar_2020_excel.csv', sep = ";")

# %% [markdown]
# 6. Concatene con pd.concat de dos formas:
#
# dolar_2019 y dolar_2020_txt solo con el argumento axis=1 guardandolo en el dataframe df_concat_1
# dolar_2019 y dolar_2020_txt solo con el argumento axis=0 guardandolo en el dataframe df_concat_0 ¿Qué problema podríamos tener con las columnas en df_concat_1 y en los índices en df_concat_0?

# %%
df_concat_1 = pd.concat([dolar_2019,dolar_2020_txt],axis=1)
df_concat_0 = pd.concat([dolar_2019,dolar_2020_txt],axis=0)
df_concat_0.head()
# Out:
#    Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# 0  1.0     NaN  657.81  651.79  678.53     NaN     NaN  679.15  700.82
# 1  2.0  694.77     NaN     NaN  672.56  678.71     NaN  677.62  704.88
# 2  3.0  697.09     NaN     NaN  670.05  683.31  709.80  681.30     NaN
# 3  4.0  697.64  655.39  656.57  667.55     NaN  704.59  680.48     NaN
# 4  5.0     NaN  653.80  659.07  666.32     NaN  696.78  677.64  711.13
#
#       Sep     Oct     Nov     Dic    Year
# 0     NaN  728.21     NaN     NaN  2019.0
# 1  720.20  729.38     NaN  812.13  2019.0
# 2  724.72  727.80     NaN  804.29  2019.0
# 3  725.69  719.53  735.05  802.44  2019.0
# 4  723.30     NaN  736.66  796.75  2019.0

# %%
df_concat_1.head()
# Out:
#    Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# 0  1.0     NaN  657.81  651.79  678.53     NaN     NaN  679.15  700.82
# 1  2.0  694.77     NaN     NaN  672.56  678.71     NaN  677.62  704.88
# 2  3.0  697.09     NaN     NaN  670.05  683.31  709.80  681.30     NaN
# 3  4.0  697.64  655.39  656.57  667.55     NaN  704.59  680.48     NaN
# 4  5.0     NaN  653.80  659.07  666.32     NaN  696.78  677.64  711.13
#
#       Sep  ...     Abr     May     Jun     Jul     Ago     Sep     Oct  \
# 0     NaN  ...  852.03     NaN  806.32  821.23     NaN  776.46  788.15
# 1  720.20  ...  863.81     NaN  796.46  816.29     NaN  770.59  785.04
# 2  724.72  ...  861.89     NaN  782.86  803.98  757.06  771.45     NaN
# 3  725.69  ...     NaN  837.92  769.13     NaN  761.34  773.71     NaN
# 4  723.30  ...     NaN  838.74  775.58     NaN  767.98     NaN  790.81
#
#       Nov     Dic    Year
# 0     NaN  767.29  2020.0
# 1  771.92  760.16  2020.0
# 2  769.17  755.34  2020.0
# ...
